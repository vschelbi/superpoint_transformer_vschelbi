# %%
import pandas as pd
import re

def parse_input_string(input_str):
    """
    Parses the input string into a dictionary with metrics as keys and their values.
    """
    rows = re.findall(r'│\s*(.*?)\s*│\s*(.*?)\s*│', input_str)
    parsed_data = {}
    
    for row in rows:
        metric = row[0].strip()
        value = row[1].strip()
        if value:  # Convert to float if value is not empty
            parsed_data[metric] = float(value)
        else:
            parsed_data[metric] = None
    
    return parsed_data

# List of input strings
input_strings = [
    """
    ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
    ┃              Test metric              ┃             DataLoader 0             ┃
    ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
    │           test/affinity_f1            │          98.87664031982422           │
    │           test/affinity_oa            │          97.96617126464844           │
    │        test/edge_affinity_loss        │         0.06379392743110657          │
    │             test/f1_Tree              │           97.4358901977539           │
    │   test/instance_iou_Ground and low    │          98.52467346191406           │
    │              vegetation               │                                      │
    │        test/instance_iou_Tree         │            98.41552734375            │
    │          test/instance_macc           │          99.20912170410156           │
    │          test/instance_miou           │          98.47010040283203           │
    │           test/instance_oa            │          99.23014068603516           │
    │  test/iou_Ground and low vegetation   │          99.70673370361328           │
    │             test/iou_Tree             │          99.68854522705078           │
    │               test/loss               │          6.5373148918151855          │
    │               test/macc               │          99.84504699707031           │
    │               test/miou               │          99.69763946533203           │
    │              test/mprec               │                100.0                 │
    │               test/mrec               │                 97.5                 │
    │                test/oa                │          99.84872436523438           │
    │                test/pq                │          95.28414916992188           │
    │   test/pq_Ground and low vegetation   │          98.52467346191406           │
    │             test/pq_Tree              │          92.04364013671875           │
    │             test/pq_stuff             │          98.52467346191406           │
    │             test/pq_thing             │          92.04364013671875           │
    │              test/pqmod               │           95.2841567993164           │
    │          test/precision_Tree          │                100.0                 │
    │           test/recall_Tree            │                 95.0                 │
    │                test/rq                │          98.71794891357422           │
    │          test/semantic_loss           │         0.15792210400104523          │
    │                test/sq                │           96.4952621459961           │
    └───────────────────────────────────────┴──────────────────────────────────────┘
    """,
    """
    ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
    ┃              Test metric              ┃             DataLoader 0             ┃
    ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
    │           test/affinity_f1            │           93.5337905883789           │
    │           test/affinity_oa            │          90.27178192138672           │
    │        test/edge_affinity_loss        │          0.2483302503824234          │
    │             test/f1_Tree              │          62.09150695800781           │
    │   test/instance_iou_Ground and low    │           98.8526382446289           │
    │              vegetation               │                                      │
    │        test/instance_iou_Tree         │          99.50946807861328           │
    │          test/instance_macc           │           99.703369140625            │
    │          test/instance_miou           │           99.1810531616211           │
    │           test/instance_oa            │          99.65518188476562           │
    │  test/iou_Ground and low vegetation   │          99.17787170410156           │
    │             test/iou_Tree             │           99.6495590209961           │
    │               test/loss               │          24.996814727783203          │
    │               test/macc               │           99.7799072265625           │
    │               test/miou               │          99.41371154785156           │
    │              test/mprec               │          82.53424835205078           │
    │               test/mrec               │               79.6875                │
    │                test/oa                │          99.75367736816406           │
    │                test/pq                │          74.62820434570312           │
    │   test/pq_Ground and low vegetation   │          98.76371002197266           │
    │             test/pq_Tree              │          50.492698669433594          │
    │             test/pq_stuff             │          98.76371002197266           │
    │             test/pq_thing             │          50.492698669433594          │
    │              test/pqmod               │           74.6281967163086           │
    │          test/precision_Tree          │          65.06849670410156           │
    │           test/recall_Tree            │                59.375                │
    │                test/rq                │           81.0457534790039           │
    │          test/semantic_loss           │         0.16379068791866302          │
    │                test/sq                │          90.04176330566406           │
    └───────────────────────────────────────┴──────────────────────────────────────┘
    """,
    """
    ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃              Test metric              ┃             DataLoader 0             ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│           test/affinity_f1            │          88.25067138671875           │
│           test/affinity_oa            │          81.92385864257812           │
│        test/edge_affinity_loss        │          0.5281190872192383          │
│             test/f1_Tree              │          16.47058868408203           │
│   test/instance_iou_Ground and low    │          97.83026123046875           │
│              vegetation               │                                      │
│        test/instance_iou_Tree         │          98.08705139160156           │
│          test/instance_macc           │          99.02881622314453           │
│          test/instance_miou           │          97.95865631103516           │
│           test/instance_oa            │           98.9729232788086           │
│  test/iou_Ground and low vegetation   │           96.9156494140625           │
│             test/iou_Tree             │          97.28075408935547           │
│               test/loss               │          54.67022705078125           │
│               test/macc               │          98.60914611816406           │
│               test/miou               │          97.09820556640625           │
│              test/mprec               │          66.66667175292969           │
│               test/mrec               │               55.46875               │
│                test/oa                │          98.53364562988281           │
│                test/pq                │             43.923828125             │
│   test/pq_Ground and low vegetation   │          73.99425506591797           │
│             test/pq_Tree              │          13.853401184082031          │
│             test/pq_stuff             │          73.99425506591797           │
│             test/pq_thing             │          13.853401184082031          │
│              test/pqmod               │             43.923828125             │
│          test/precision_Tree          │          33.333335876464844          │
│           test/recall_Tree            │               10.9375                │
│                test/rq                │          58.235294342041016          │
│          test/semantic_loss           │          1.8583189249038696          │
│                test/sq                │          79.05209350585938           │
└───────────────────────────────────────┴──────────────────────────────────────┘
    """,
    """
    ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃              Test metric              ┃             DataLoader 0             ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│           test/affinity_f1            │           93.1876449584961           │
│           test/affinity_oa            │           89.0339126586914           │
│        test/edge_affinity_loss        │          0.2691745460033417          │
│             test/f1_Tree              │          48.421051025390625          │
│   test/instance_iou_Ground and low    │           98.7178726196289           │
│              vegetation               │                                      │
│        test/instance_iou_Tree         │          99.81880950927734           │
│          test/instance_macc           │          99.76942443847656           │
│          test/instance_miou           │          99.26834106445312           │
│           test/instance_oa            │          99.84098815917969           │
│  test/iou_Ground and low vegetation   │          99.01505279541016           │
│             test/iou_Tree             │          99.86112976074219           │
│               test/loss               │          26.994544982910156          │
│               test/macc               │          99.81571960449219           │
│               test/miou               │          99.43809509277344           │
│              test/mprec               │          72.11538696289062           │
│               test/mrec               │          76.74418640136719           │
│                test/oa                │          99.87814331054688           │
│                test/pq                │           68.8677978515625           │
│   test/pq_Ground and low vegetation   │          98.72503662109375           │
│             test/pq_Tree              │          39.01055908203125           │
│             test/pq_stuff             │          98.72503662109375           │
│             test/pq_thing             │          39.01055908203125           │
│              test/pqmod               │           68.8677978515625           │
│          test/precision_Tree          │          44.23076629638672           │
│           test/recall_Tree            │          53.488372802734375          │
│                test/rq                │          74.21052551269531           │
│          test/semantic_loss           │         0.07709129899740219          │
│                test/sq                │          89.64515686035156           │
└───────────────────────────────────────┴──────────────────────────────────────┘
    """,
    """
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃              Test metric              ┃             DataLoader 0             ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│           test/affinity_f1            │          90.54972839355469           │
│           test/affinity_oa            │          83.89295196533203           │
│        test/edge_affinity_loss        │          0.4130495488643646          │
│             test/f1_Tree              │          20.289854049682617          │
│   test/instance_iou_Ground and low    │          89.57877349853516           │
│              vegetation               │                                      │
│        test/instance_iou_Tree         │          95.93889617919922           │
│          test/instance_macc           │           94.918212890625            │
│          test/instance_miou           │          92.75883483886719           │
│           test/instance_oa            │          96.98973083496094           │
│  test/iou_Ground and low vegetation   │          90.23583221435547           │
│             test/iou_Tree             │          96.18294525146484           │
│               test/loss               │          43.13762283325195           │
│               test/macc               │          95.24211883544922           │
│               test/miou               │          93.20938873291016           │
│              test/mprec               │          60.29411697387695           │
│               test/mrec               │          60.000003814697266          │
│                test/oa                │          97.17830657958984           │
│                test/pq                │          39.861602783203125          │
│   test/pq_Ground and low vegetation   │          67.04288482666016           │
│             test/pq_Tree              │          12.680317878723145          │
│             test/pq_stuff             │          67.04288482666016           │
│             test/pq_thing             │          12.680317878723145          │
│              test/pqmod               │          39.861602783203125          │
│          test/precision_Tree          │          20.58823585510254           │
│           test/recall_Tree            │                 20.0                 │
│                test/rq                │          60.14492416381836           │
│          test/semantic_loss           │          1.832669973373413           │
│                test/sq                │          64.76937103271484           │
└───────────────────────────────────────┴──────────────────────────────────────┘
    """,
    """
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              93.53826904296875              │
│              test/affinity_oa               │              88.6050796508789               │
│           test/edge_affinity_loss           │             0.36648690700531006             │
│                test/f1_Tree                 │              33.33333206176758              │
│ test/instance_iou_Ground and low vegetation │              96.75236511230469              │
│           test/instance_iou_Tree            │              97.10690307617188              │
│             test/instance_macc              │              98.50040435791016              │
│             test/instance_miou              │              96.92963409423828              │
│              test/instance_oa               │              98.44615173339844              │
│     test/iou_Ground and low vegetation      │              96.9156494140625               │
│                test/iou_Tree                │              97.28075408935547              │
│                  test/loss                  │              38.50679016113281              │
│                  test/macc                  │              98.60914611816406              │
│                  test/miou                  │              97.09820556640625              │
│                 test/mprec                  │              62.70492172241211              │
│                  test/mrec                  │                  74.21875                   │
│                   test/oa                   │              98.53364562988281              │
│                   test/pq                   │              49.63139343261719              │
│      test/pq_Ground and low vegetation      │              73.62247467041016              │
│                test/pq_Tree                 │             25.640308380126953              │
│                test/pq_stuff                │              73.62247467041016              │
│                test/pq_thing                │             25.640308380126953              │
│                 test/pqmod                  │              49.63139343261719              │
│             test/precision_Tree             │             25.409835815429688              │
│              test/recall_Tree               │                   48.4375                   │
│                   test/rq                   │              66.66666412353516              │
│             test/semantic_loss              │             1.8581013679504395              │
│                   test/sq                   │              75.27169799804688              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
    """,
    """
    ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              90.0948486328125               │
│              test/affinity_oa               │              83.77262115478516              │
│           test/edge_affinity_loss           │             0.48425552248954773             │
│                test/f1_Tree                 │              36.6412239074707               │
│ test/instance_iou_Ground and low vegetation │              97.35343933105469              │
│           test/instance_iou_Tree            │              97.64908599853516              │
│             test/instance_macc              │              98.7803955078125               │
│             test/instance_miou              │              97.50126647949219              │
│              test/instance_oa               │              98.73930358886719              │
│     test/iou_Ground and low vegetation      │              97.08104705810547              │
│                test/iou_Tree                │              97.43778228759766              │
│                  test/loss                  │              50.11210250854492              │
│                  test/macc                  │              98.6763687133789               │
│                  test/miou                  │              97.25941467285156              │
│                 test/mprec                  │              67.91044616699219              │
│                  test/mrec                  │                    68.75                    │
│                   test/oa                   │              98.61663055419922              │
│                   test/pq                   │              50.44857406616211              │
│      test/pq_Ground and low vegetation      │              74.04905700683594              │
│                test/pq_Tree                 │             26.848094940185547              │
│                test/pq_stuff                │              74.04905700683594              │
│                test/pq_thing                │             26.848094940185547              │
│                 test/pqmod                  │              50.44857406616211              │
│             test/precision_Tree             │              35.82089614868164              │
│              test/recall_Tree               │                    37.5                     │
│                   test/rq                   │              68.32061004638672              │
│             test/semantic_loss              │             1.6865507364273071              │
│                   test/sq                   │              73.66099548339844              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
    """,
    """
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              85.04026794433594              │
│              test/affinity_oa               │              76.90228271484375              │
│           test/edge_affinity_loss           │             0.5771410465240479              │
│                test/f1_Tree                 │              22.47191047668457              │
│ test/instance_iou_Ground and low vegetation │              89.5644760131836               │
│           test/instance_iou_Tree            │              95.95188903808594              │
│             test/instance_macc              │              94.86505889892578              │
│             test/instance_miou              │              92.7581787109375               │
│              test/instance_oa               │              96.99568939208984              │
│     test/iou_Ground and low vegetation      │              90.03973388671875              │
│                test/iou_Tree                │              96.11583709716797              │
│                  test/loss                  │              59.61272430419922              │
│                  test/macc                  │              95.11236572265625              │
│                  test/miou                  │              93.07778930664062              │
│                 test/mprec                  │              59.25925827026367              │
│                  test/mrec                  │              64.28571319580078              │
│                   test/oa                   │              97.12522888183594              │
│                   test/pq                   │             41.166446685791016              │
│      test/pq_Ground and low vegetation      │              66.90137481689453              │
│                test/pq_Tree                 │             15.431517601013184              │
│                test/pq_stuff                │              66.90137481689453              │
│                test/pq_thing                │             15.431517601013184              │
│                 test/pqmod                  │             41.166446685791016              │
│             test/precision_Tree             │             18.518518447875977              │
│              test/recall_Tree               │             28.571430206298828              │
│                   test/rq                   │              61.23595428466797              │
│             test/semantic_loss              │              1.89862060546875               │
│                   test/sq                   │              67.78581237792969              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              93.19109344482422              │
│              test/affinity_oa               │              89.18991088867188              │
│           test/edge_affinity_loss           │             0.2720945477485657              │
│                test/f1_Tree                 │              60.70763397216797              │
│ test/instance_iou_Ground and low vegetation │              92.9603500366211               │
│           test/instance_iou_Tree            │              97.02975463867188              │
│             test/instance_macc              │              98.24942016601562              │
│             test/instance_miou              │              94.99505615234375              │
│              test/instance_oa               │              97.86654663085938              │
│     test/iou_Ground and low vegetation      │              98.70756530761719              │
│                test/iou_Tree                │              99.47110748291016              │
│                  test/loss                  │             27.504308700561523              │
│                  test/macc                  │              99.53922271728516              │
│                  test/miou                  │              99.08934020996094              │
│                 test/mprec                  │              83.71745300292969              │
│                  test/mrec                  │              75.1543197631836               │
│                   test/oa                   │              99.62328338623047              │
│                   test/pq                   │              70.4662094116211               │
│      test/pq_Ground and low vegetation      │              89.20423126220703              │
│                test/pq_Tree                 │              51.72818374633789              │
│                test/pq_stuff                │              89.20423126220703              │
│                test/pq_thing                │              51.72818374633789              │
│                 test/pqmod                  │              72.6963119506836               │
│             test/precision_Tree             │              76.52581787109375              │
│              test/recall_Tree               │              50.30864334106445              │
│                   test/rq                   │              77.97286224365234              │
│             test/semantic_loss              │             0.2948525846004486              │
│                   test/sq                   │              89.43656921386719              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              98.87666320800781              │
│              test/affinity_oa               │              97.96617126464844              │
│           test/edge_affinity_loss           │             0.06381392478942871             │
│                test/f1_Tree                 │              97.4358901977539               │
│ test/instance_iou_Ground and low vegetation │              99.56507873535156              │
│           test/instance_iou_Tree            │              99.53768157958984              │
│             test/instance_macc              │              99.7702865600586               │
│             test/instance_miou              │              99.55137634277344              │
│              test/instance_oa               │              99.77539825439453              │
│     test/iou_Ground and low vegetation      │              99.70673370361328              │
│                test/iou_Tree                │              99.68854522705078              │
│                  test/loss                  │              6.53926420211792               │
│                  test/macc                  │              99.84504699707031              │
│                  test/miou                  │              99.69763946533203              │
│                 test/mprec                  │                    100.0                    │
│                  test/mrec                  │                    97.5                     │
│                   test/oa                   │              99.84872436523438              │
│                   test/pq                   │              96.20685577392578              │
│      test/pq_Ground and low vegetation      │              99.56507873535156              │
│                test/pq_Tree                 │              92.84862518310547              │
│                test/pq_stuff                │              99.56507873535156              │
│                test/pq_thing                │              92.84862518310547              │
│                 test/pqmod                  │              96.20685577392578              │
│             test/precision_Tree             │                    100.0                    │
│              test/recall_Tree               │                    95.0                     │
│                   test/rq                   │              98.71794891357422              │
│             test/semantic_loss              │             0.15787187218666077             │
│                   test/sq                   │              97.42855072021484              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              93.53302764892578              │
│              test/affinity_oa               │                90.2705078125                │
│           test/edge_affinity_loss           │              0.248321995139122              │
│                test/f1_Tree                 │              75.63636016845703              │
│ test/instance_iou_Ground and low vegetation │              99.03475952148438              │
│           test/instance_iou_Tree            │              99.58816528320312              │
│             test/instance_macc              │              99.73878479003906              │
│             test/instance_miou              │              99.31146240234375              │
│              test/instance_oa               │              99.71048736572266              │
│     test/iou_Ground and low vegetation      │              99.17787170410156              │
│                test/iou_Tree                │              99.6495590209961               │
│                  test/loss                  │             24.995986938476562              │
│                  test/macc                  │              99.7799072265625               │
│                  test/miou                  │              99.41371154785156              │
│                 test/mprec                  │              95.6140365600586               │
│                  test/mrec                  │              82.29813385009766              │
│                   test/oa                   │              99.75367736816406              │
│                   test/pq                   │              81.93497467041016              │
│      test/pq_Ground and low vegetation      │              98.96886444091797              │
│                test/pq_Tree                 │              64.90108489990234              │
│                test/pq_stuff                │              98.96886444091797              │
│                test/pq_thing                │              64.90108489990234              │
│                 test/pqmod                  │              81.93497467041016              │
│             test/precision_Tree             │              91.22806549072266              │
│              test/recall_Tree               │              64.59626770019531              │
│                   test/rq                   │              87.81818389892578              │
│             test/semantic_loss              │             0.16378773748874664             │
│                   test/sq                   │              92.3877944946289               │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              88.25466918945312              │
│              test/affinity_oa               │              81.92936706542969              │
│           test/edge_affinity_loss           │             0.5279595851898193              │
│                test/f1_Tree                 │             16.666667938232422              │
│ test/instance_iou_Ground and low vegetation │              97.07833862304688              │
│           test/instance_iou_Tree            │              97.40150451660156              │
│             test/instance_macc              │              98.63262176513672              │
│             test/instance_miou              │              97.23992156982422              │
│              test/instance_oa               │              98.60550689697266              │
│     test/iou_Ground and low vegetation      │              96.9156494140625               │
│                test/iou_Tree                │              97.28075408935547              │
│                  test/loss                  │              54.65406036376953              │
│                  test/macc                  │              98.60914611816406              │
│                  test/miou                  │              97.09820556640625              │
│                 test/mprec                  │                    67.5                     │
│                  test/mrec                  │                  55.46875                   │
│                   test/oa                   │              98.53364562988281              │
│                   test/pq                   │              43.56499481201172              │
│      test/pq_Ground and low vegetation      │              74.0173110961914               │
│                test/pq_Tree                 │             13.112672805786133              │
│                test/pq_stuff                │              74.0173110961914               │
│                test/pq_thing                │             13.112672805786133              │
│                 test/pqmod                  │              43.56499099731445              │
│             test/precision_Tree             │                    35.0                     │
│              test/recall_Tree               │                   10.9375                   │
│                   test/rq                   │              58.33333206176758              │
│             test/semantic_loss              │             1.8581011295318604              │
│                   test/sq                   │              76.34667205810547              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              93.18685913085938              │
│              test/affinity_oa               │              89.03244018554688              │
│           test/edge_affinity_loss           │             0.26920440793037415             │
│                test/f1_Tree                 │                    62.5                     │
│ test/instance_iou_Ground and low vegetation │              98.89398193359375              │
│           test/instance_iou_Tree            │              99.84413146972656              │
│             test/instance_macc              │              99.74432373046875              │
│             test/instance_miou              │              99.36905670166016              │
│              test/instance_oa               │              99.86319732666016              │
│     test/iou_Ground and low vegetation      │              99.01505279541016              │
│                test/iou_Tree                │              99.86112976074219              │
│                  test/loss                  │             26.997533798217773              │
│                  test/macc                  │              99.81571960449219              │
│                  test/miou                  │              99.43809509277344              │
│                 test/mprec                  │              83.78378295898438              │
│                  test/mrec                  │              79.06977081298828              │
│                   test/oa                   │              99.87814331054688              │
│                   test/pq                   │              76.73947143554688              │
│      test/pq_Ground and low vegetation      │              98.9005355834961               │
│                test/pq_Tree                 │             54.578407287597656              │
│                test/pq_stuff                │              98.9005355834961               │
│                test/pq_thing                │             54.578407287597656              │
│                 test/pqmod                  │              76.73947143554688              │
│             test/precision_Tree             │              67.56756591796875              │
│              test/recall_Tree               │              58.13953399658203              │
│                   test/rq                   │                    81.25                    │
│             test/semantic_loss              │             0.07709357887506485             │
│                   test/sq                   │              93.11299133300781              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              90.55024719238281              │
│              test/affinity_oa               │              83.89418029785156              │
│           test/edge_affinity_loss           │             0.41298365592956543             │
│                test/f1_Tree                 │             31.746028900146484              │
│ test/instance_iou_Ground and low vegetation │              88.5289535522461               │
│           test/instance_iou_Tree            │              95.54936981201172              │
│             test/instance_macc              │              94.38104248046875              │
│             test/instance_miou              │              92.0391616821289               │
│              test/instance_oa               │              96.68724060058594              │
│     test/iou_Ground and low vegetation      │              90.23583221435547              │
│                test/iou_Tree                │              96.18294525146484              │
│                  test/loss                  │              43.13142013549805              │
│                  test/macc                  │              95.24211883544922              │
│                  test/miou                  │              93.20938873291016              │
│                 test/mprec                  │              67.85714721679688              │
│                  test/mrec                  │              64.28571319580078              │
│                   test/oa                   │              97.17830657958984              │
│                   test/pq                   │             43.966243743896484              │
│      test/pq_Ground and low vegetation      │              66.2614517211914               │
│                test/pq_Tree                 │             21.671031951904297              │
│                test/pq_stuff                │              66.2614517211914               │
│                test/pq_thing                │             21.671031951904297              │
│                 test/pqmod                  │             43.966243743896484              │
│             test/precision_Tree             │              35.71428680419922              │
│              test/recall_Tree               │             28.571430206298828              │
│                   test/rq                   │              65.87301635742188              │
│             test/semantic_loss              │             1.8330519199371338              │
│                   test/sq                   │              67.26260375976562              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              93.19132232666016              │
│              test/affinity_oa               │              89.19025421142578              │
│           test/edge_affinity_loss           │             0.2720945179462433              │
│                test/f1_Tree                 │             59.430606842041016              │
│ test/instance_iou_Ground and low vegetation │              98.25419616699219              │
│           test/instance_iou_Tree            │              99.28401947021484              │
│             test/instance_macc              │              99.39157104492188              │
│             test/instance_miou              │              98.76910400390625              │
│              test/instance_oa               │              99.48966979980469              │
│     test/iou_Ground and low vegetation      │              98.70756530761719              │
│                test/iou_Tree                │              99.47110748291016              │
│                  test/loss                  │             27.504308700561523              │
│                  test/macc                  │              99.53922271728516              │
│                  test/miou                  │              99.08934020996094              │
│                 test/mprec                  │              84.93724060058594              │
│                  test/mrec                  │              75.85139465332031              │
│                   test/oa                   │              99.62328338623047              │
│                   test/pq                   │              71.80956268310547              │
│      test/pq_Ground and low vegetation      │              93.5590591430664               │
│                test/pq_Tree                 │              50.0600700378418               │
│                test/pq_stuff                │              93.5590591430664               │
│                test/pq_thing                │              50.0600700378418               │
│                 test/pqmod                  │              71.80956268310547              │
│             test/precision_Tree             │              69.87448120117188              │
│              test/recall_Tree               │              51.70278549194336              │
│                   test/rq                   │              79.71530151367188              │
│             test/semantic_loss              │             0.29485204815864563             │
│                   test/sq                   │              88.89592742919922              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              93.19109344482422              │
│              test/affinity_oa               │              89.18991088867188              │
│           test/edge_affinity_loss           │             0.27209457755088806             │
│                test/f1_Tree                 │              62.6151008605957               │
│ test/instance_iou_Ground and low vegetation │              97.35792541503906              │
│           test/instance_iou_Tree            │              98.90511322021484              │
│             test/instance_macc              │              99.22972106933594              │
│             test/instance_miou              │              98.13151550292969              │
│              test/instance_oa               │              99.21985626220703              │
│     test/iou_Ground and low vegetation      │              98.70756530761719              │
│                test/iou_Tree                │              99.47110748291016              │
│                  test/loss                  │             27.504308700561523              │
│                  test/macc                  │              99.53922271728516              │
│                  test/miou                  │              99.08934020996094              │
│                 test/mprec                  │              88.63636016845703              │
│                  test/mrec                  │              76.31578826904297              │
│                   test/oa                   │              99.62328338623047              │
│                   test/pq                   │              73.40647888183594              │
│      test/pq_Ground and low vegetation      │              92.96311950683594              │
│                test/pq_Tree                 │              53.84982681274414              │
│                test/pq_stuff                │              92.96311950683594              │
│                test/pq_thing                │              53.84982681274414              │
│                 test/pqmod                  │              73.40647888183594              │
│             test/precision_Tree             │              77.2727279663086               │
│              test/recall_Tree               │              52.6315803527832               │
│                   test/rq                   │              81.30755615234375              │
│             test/semantic_loss              │             0.2948519289493561              │
│                   test/sq                   │              89.48223876953125              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              98.87666320800781              │
│              test/affinity_oa               │              97.96617126464844              │
│           test/edge_affinity_loss           │             0.06381399929523468             │
│                test/f1_Tree                 │              97.4358901977539               │
│ test/instance_iou_Ground and low vegetation │              99.68374633789062              │
│           test/instance_iou_Tree            │              99.66436004638672              │
│             test/instance_macc              │              99.83421325683594              │
│             test/instance_miou              │              99.67405700683594              │
│              test/instance_oa               │              99.83690643310547              │
│     test/iou_Ground and low vegetation      │              99.70673370361328              │
│                test/iou_Tree                │              99.68854522705078              │
│                  test/loss                  │              6.539272308349609              │
│                  test/macc                  │              99.84504699707031              │
│                  test/miou                  │              99.69763946533203              │
│                 test/mprec                  │                    100.0                    │
│                  test/mrec                  │                    97.5                     │
│                   test/oa                   │              99.84872436523438              │
│                   test/pq                   │              96.36883544921875              │
│      test/pq_Ground and low vegetation      │              99.68374633789062              │
│                test/pq_Tree                 │              93.0539321899414               │
│                test/pq_stuff                │              99.68374633789062              │
│                test/pq_thing                │              93.0539321899414               │
│                 test/pqmod                  │              96.36883544921875              │
│             test/precision_Tree             │                    100.0                    │
│              test/recall_Tree               │                    95.0                     │
│                   test/rq                   │              98.71794891357422              │
│             test/semantic_loss              │             0.15787196159362793             │
│                   test/sq                   │              97.5932388305664               │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              93.53302764892578              │
│              test/affinity_oa               │                90.2705078125                │
│           test/edge_affinity_loss           │             0.24832192063331604             │
│                test/f1_Tree                 │              75.53956604003906              │
│ test/instance_iou_Ground and low vegetation │              98.58614349365234              │
│           test/instance_iou_Tree            │              99.3939208984375               │
│             test/instance_macc              │              99.64483642578125              │
│             test/instance_miou              │              98.99003601074219              │
│              test/instance_oa               │              99.57395935058594              │
│     test/iou_Ground and low vegetation      │              99.17787170410156              │
│                test/iou_Tree                │              99.6495590209961               │
│                  test/loss                  │              24.99597930908203              │
│                  test/macc                  │              99.7799072265625               │
│                  test/miou                  │              99.41371154785156              │
│                 test/mprec                  │              94.87179565429688              │
│                  test/mrec                  │              82.60870361328125              │
│                   test/oa                   │              99.75367736816406              │
│                   test/pq                   │              81.67633056640625              │
│      test/pq_Ground and low vegetation      │              98.6258773803711               │
│                test/pq_Tree                 │              64.72677612304688              │
│                test/pq_stuff                │              98.6258773803711               │
│                test/pq_thing                │              64.72677612304688              │
│                 test/pqmod                  │              81.67633056640625              │
│             test/precision_Tree             │              89.74359130859375              │
│              test/recall_Tree               │              65.21739196777344              │
│                   test/rq                   │              87.76978302001953              │
│             test/semantic_loss              │             0.16378775238990784             │
│                   test/sq                   │              92.15589904785156              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              93.53302764892578              │
│              test/affinity_oa               │                90.2705078125                │
│           test/edge_affinity_loss           │             0.24832192063331604             │
│                test/f1_Tree                 │              75.53956604003906              │
│ test/instance_iou_Ground and low vegetation │              98.58614349365234              │
│           test/instance_iou_Tree            │              99.3939208984375               │
│             test/instance_macc              │              99.64483642578125              │
│             test/instance_miou              │              98.99003601074219              │
│              test/instance_oa               │              99.57395935058594              │
│     test/iou_Ground and low vegetation      │              99.17787170410156              │
│                test/iou_Tree                │              99.6495590209961               │
│                  test/loss                  │              24.99597930908203              │
│                  test/macc                  │              99.7799072265625               │
│                  test/miou                  │              99.41371154785156              │
│                 test/mprec                  │              94.87179565429688              │
│                  test/mrec                  │              82.60870361328125              │
│                   test/oa                   │              99.75367736816406              │
│                   test/pq                   │              81.67633056640625              │
│      test/pq_Ground and low vegetation      │              98.6258773803711               │
│                test/pq_Tree                 │              64.72677612304688              │
│                test/pq_stuff                │              98.6258773803711               │
│                test/pq_thing                │              64.72677612304688              │
│                 test/pqmod                  │              81.67633056640625              │
│             test/precision_Tree             │              89.74359130859375              │
│              test/recall_Tree               │              65.21739196777344              │
│                   test/rq                   │              87.76978302001953              │
│             test/semantic_loss              │             0.16378775238990784             │
│                   test/sq                   │              92.15589904785156              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              88.25466918945312              │
│              test/affinity_oa               │              81.92936706542969              │
│           test/edge_affinity_loss           │             0.5279594659805298              │
│                test/f1_Tree                 │             16.666667938232422              │
│ test/instance_iou_Ground and low vegetation │              96.68806457519531              │
│           test/instance_iou_Tree            │              97.03179931640625              │
│             test/instance_macc              │              98.45416259765625              │
│             test/instance_miou              │              96.85993194580078              │
│              test/instance_oa               │              98.40977478027344              │
│     test/iou_Ground and low vegetation      │              96.9156494140625               │
│                test/iou_Tree                │              97.28075408935547              │
│                  test/loss                  │             54.654048919677734              │
│                  test/macc                  │              98.60914611816406              │
│                  test/miou                  │              97.09820556640625              │
│                 test/mprec                  │                    67.5                     │
│                  test/mrec                  │                  55.46875                   │
│                   test/oa                   │              98.53364562988281              │
│                   test/pq                   │             42.953006744384766              │
│      test/pq_Ground and low vegetation      │              73.87564086914062              │
│                test/pq_Tree                 │             12.030367851257324              │
│                test/pq_stuff                │              73.87564086914062              │
│                test/pq_thing                │             12.030367851257324              │
│                 test/pqmod                  │             42.953006744384766              │
│             test/precision_Tree             │                    35.0                     │
│              test/recall_Tree               │                   10.9375                   │
│                   test/rq                   │              58.33333206176758              │
│             test/semantic_loss              │              1.858101487159729              │
│                   test/sq                   │              73.02892303466797              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              93.18685913085938              │
│              test/affinity_oa               │              89.03244018554688              │
│           test/edge_affinity_loss           │             0.2692044973373413              │
│                test/f1_Tree                 │             63.414634704589844              │
│ test/instance_iou_Ground and low vegetation │              98.95697021484375              │
│           test/instance_iou_Tree            │              99.85299682617188              │
│             test/instance_macc              │              99.77603912353516              │
│             test/instance_miou              │              99.40498352050781              │
│              test/instance_oa               │              99.87098693847656              │
│     test/iou_Ground and low vegetation      │              99.01505279541016              │
│                test/iou_Tree                │              99.86112976074219              │
│                  test/loss                  │             26.997543334960938              │
│                  test/macc                  │              99.81571960449219              │
│                  test/miou                  │              99.43809509277344              │
│                 test/mprec                  │              83.33333587646484              │
│                  test/mrec                  │              80.23255920410156              │
│                   test/oa                   │              99.87814331054688              │
│                   test/pq                   │              77.21202087402344              │
│      test/pq_Ground and low vegetation      │              98.96656036376953              │
│                test/pq_Tree                 │             55.457489013671875              │
│                test/pq_stuff                │              98.96656036376953              │
│                test/pq_thing                │             55.457489013671875              │
│                 test/pqmod                  │              77.21202087402344              │
│             test/precision_Tree             │              66.66667175292969              │
│              test/recall_Tree               │              60.46511459350586              │
│                   test/rq                   │              81.70731353759766              │
│             test/semantic_loss              │             0.07709359377622604             │
│                   test/sq                   │              93.20938110351562              │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
""",
"""
┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
┃                 Test metric                 ┃                DataLoader 0                 ┃
┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
│              test/affinity_f1               │              90.55024719238281              │
│              test/affinity_oa               │              83.89418029785156              │
│           test/edge_affinity_loss           │             0.4129835069179535              │
│                test/f1_Tree                 │             33.333335876464844              │
│ test/instance_iou_Ground and low vegetation │              87.8531494140625               │
│           test/instance_iou_Tree            │              95.3005142211914               │
│             test/instance_macc              │              94.04154968261719              │
│             test/instance_miou              │              91.57682800292969              │
│              test/instance_oa               │              96.49263763427734              │
│     test/iou_Ground and low vegetation      │              90.23583221435547              │
│                test/iou_Tree                │              96.18294525146484              │
│                  test/loss                  │             43.131404876708984              │
│                  test/macc                  │              95.24211883544922              │
│                  test/miou                  │              93.20938873291016              │
│                 test/mprec                  │                    70.0                     │
│                  test/mrec                  │              64.28571319580078              │
│                   test/oa                   │              97.17830657958984              │
│                   test/pq                   │              44.25497055053711              │
│      test/pq_Ground and low vegetation      │              65.74491882324219              │
│                test/pq_Tree                 │             22.765026092529297              │
│                test/pq_stuff                │              65.74491882324219              │
│                test/pq_thing                │             22.765026092529297              │
│                 test/pqmod                  │              44.25497055053711              │
│             test/precision_Tree             │                    40.0                     │
│              test/recall_Tree               │             28.571430206298828              │
│                   test/rq                   │              66.66667175292969              │
│             test/semantic_loss              │             1.8330552577972412              │
│                   test/sq                   │              67.0199966430664               │
└─────────────────────────────────────────────┴─────────────────────────────────────────────┘
"""
]

# Initialize an empty DataFrame to store all the parsed data
df_list = []

# Parse each input string and append the results into the list of DataFrames
for input_str in input_strings:
    parsed_data = parse_input_string(input_str)
    temp_df = pd.DataFrame(parsed_data, index=[0])  # Create a single-row DataFrame
    df_list.append(temp_df)

# Concatenate all DataFrames into a single DataFrame
final_df = pd.concat(df_list, ignore_index=True)

# Save the DataFrame to a CSV file
final_df.to_csv('/home/valerio/Documents/Semester_Thesis/results/metrics_output.csv', index=False)

# Display the DataFrame
final_df
# Out:
#     test/affinity_f1  test/affinity_oa  test/edge_affinity_loss  test/f1_Tree  \
# 0          98.876640         97.966171                 0.063794     97.435890
# 1          93.533791         90.271782                 0.248330     62.091507
# 2          88.250671         81.923859                 0.528119     16.470589
# 3          93.187645         89.033913                 0.269175     48.421051
# 4          90.549728         83.892952                 0.413050     20.289854
# 5          93.538269         88.605080                 0.366487     33.333332
# 6          90.094849         83.772621                 0.484256     36.641224
# 7          85.040268         76.902283                 0.577141     22.471910
# 8          93.191093         89.189911                 0.272095     60.707634
# 9          98.876663         97.966171                 0.063814     97.435890
# 10         93.533028         90.270508                 0.248322     75.636360
# ...
